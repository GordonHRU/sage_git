# %%
import requests

import numpy as np
import pandas as pd
import tensorflow as tf
# assert tf.__version__.startswith('2')

# plot_model
# pip install pydot
# pip install pydotplus
import keras
from keras.callbacks import EarlyStopping, ModelCheckpoint

# pip install scikit-learn
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from keras.models import load_model

from tqdm import tqdm
import seaborn as sns
import matplotlib.pyplot as plt

import os, random, shutil, warnings, cv2  # pip install opencv-python
import json
import pickle
import joblib

import logging

from flask import Flask
from flask.views import MethodView
from PIL import Image
import io
from os import listdir

# %%
interpreter = tf.lite.Interpreter(model_path="D:/code/git_Andy/sage_git/herbs_image_detection/model.tflite")
interpreter.allocate_tensors()

# %%
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

# %%
input_shape = input_details[0]['shape']
input_data = np.array(np.random.random_sample(input_shape), dtype=np.float32)
interpreter.set_tensor(input_details[0]['index'], input_data)

# %%
interpreter.invoke()

# %%
output_data = interpreter.get_tensor(output_details[0]['index'])
output_data
# Out:
# array([[9.2571920e-01, 2.2072633e-09, 1.7297855e-10, 5.9884433e-02,
#         3.5478703e-07, 1.4396050e-02]], dtype=float32)

# %%
folder_path = "D:/code/git_Andy/sage_git/herbs_image_detection/.ipynb_checkpoints/input/test/Arive-Dantu/__4_2602646.png"
img = cv2.imread(r"{}".format(folder_path))
new_img = cv2.resize(img, (224, 224))
new_img = Image.open(folder_path)
new_img = new_img.convert("RGB")

# %%
interpreter.set_tensor(input_details[0]['index'],np.asarray(new_img))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 interpreter.set_tensor(input_details[0]['index'],np.asarray(new_img))
#
# File d:\IDE\conda\envs\jupyter-herbs\lib\site-packages\tensorflow\lite\python\interpreter.py:696, in Interpreter.set_tensor(self, tensor_index, value)
#     680 def set_tensor(self, tensor_index, value):
#     681   """Sets the value of the input tensor.
#     682
#     683   Note this copies data in `value`.
#    (...)
#     694     ValueError: If the interpreter could not set the tensor.
#     695   """
# --> 696   self._interpreter.SetTensor(tensor_index, value)
#
# ValueError: Cannot set tensor: Got value of type UINT8 but expected type FLOAT32 for input 0, name: serving_default_sequential_1_input:0

# %%
2024-05-23T06:00:54: Package                            Version
2024-05-23T06:00:54: ---------------------------------- ------------
2024-05-23T06:00:54: absl-py                            2.1.0
2024-05-23T06:00:54: adal                               1.2.7
2024-05-23T06:00:54: annotated-types                    0.7.0
2024-05-23T06:00:54: applicationinsights                0.11.10
2024-05-23T06:00:54: argcomplete                        3.3.0
2024-05-23T06:00:54: asttokens                          2.4.1
2024-05-23T06:00:54: astunparse                         1.6.3
2024-05-23T06:00:54: attrs                              23.2.0
2024-05-23T06:00:54: azure-common                       1.1.28
2024-05-23T06:00:54: azure-core                         1.30.1
2024-05-23T06:00:54: azure-graphrbac                    0.61.1
2024-05-23T06:00:54: azure-identity                     1.16.0
2024-05-23T06:00:54: azure-mgmt-authorization           4.0.0
2024-05-23T06:00:54: azure-mgmt-containerregistry       10.3.0
2024-05-23T06:00:54: azure-mgmt-core                    1.4.0
2024-05-23T06:00:54: azure-mgmt-keyvault                10.3.0
2024-05-23T06:00:54: azure-mgmt-network                 25.3.0
2024-05-23T06:00:54: azure-mgmt-resource                23.1.1
2024-05-23T06:00:54: azure-mgmt-storage                 21.1.0
2024-05-23T06:00:54: azure-storage-blob                 12.19.0
2024-05-23T06:00:54: azureml-automl-common-tools        1.56.0
2024-05-23T06:00:54: azureml-core                       1.56.0
2024-05-23T06:00:54: azureml-dataprep                   5.1.6
2024-05-23T06:00:54: azureml-dataprep-native            41.0.0
2024-05-23T06:00:54: azureml-dataprep-rslex             2.22.2
2024-05-23T06:00:54: azureml-dataset-runtime            1.56.0
2024-05-23T06:00:54: azureml-defaults                   1.56.0.post1
2024-05-23T06:00:54: azureml-inference-server-http      1.2.2
2024-05-23T06:00:54: azureml-mlflow                     1.56.0
2024-05-23T06:00:54: azureml-telemetry                  1.56.0
2024-05-23T06:00:54: backcall                           0.2.0
2024-05-23T06:00:54: backports.tempfile                 1.0
2024-05-23T06:00:54: backports.weakref                  1.0.post1
2024-05-23T06:00:54: bcrypt                             4.1.3
2024-05-23T06:00:54: blinker                            1.8.2
2024-05-23T06:00:54: Bottleneck                         1.3.5
2024-05-23T06:00:54: Brotli                             1.0.9
2024-05-23T06:00:54: cachetools                         5.3.3
2024-05-23T06:00:54: certifi                            2024.2.2
2024-05-23T06:00:54: cffi                               1.16.0
2024-05-23T06:00:54: charset-normalizer                 2.0.4
2024-05-23T06:00:54: click                              8.1.7
2024-05-23T06:00:54: cloudpickle                        2.2.1
2024-05-23T06:00:54: comm                               0.2.2
2024-05-23T06:00:54: contextlib2                        21.6.0
2024-05-23T06:00:54: cryptography                       42.0.7
2024-05-23T06:00:54: cycler                             0.12.1
2024-05-23T06:00:54: daal                               2024.3.0
2024-05-23T06:00:54: daal4py                            2024.3.0
2024-05-23T06:00:54: debugpy                            1.6.7.post1
2024-05-23T06:00:54: decorator                          5.1.1
2024-05-23T06:00:54: Deprecated                         1.2.14
2024-05-23T06:00:54: docker                             7.0.0
2024-05-23T06:00:54: entrypoints                        0.4
2024-05-23T06:00:54: executing                          2.0.1
2024-05-23T06:00:54: Flask                              2.3.2
2024-05-23T06:00:54: Flask-Cors                         3.0.10
2024-05-23T06:00:54: flatbuffers                        24.3.25
2024-05-23T06:00:54: fonttools                          4.51.0
2024-05-23T06:00:54: fusepy                             3.0.1
2024-05-23T06:00:54: gast                               0.4.0
2024-05-23T06:00:54: gitdb                              4.0.11
2024-05-23T06:00:54: GitPython                          3.1.43
2024-05-23T06:00:54: google-api-core                    2.19.0
2024-05-23T06:00:54: google-auth                        2.29.0
2024-05-23T06:00:54: google-auth-oauthlib               1.0.0
2024-05-23T06:00:54: google-pasta                       0.2.0
2024-05-23T06:00:54: googleapis-common-protos           1.63.0
2024-05-23T06:00:54: grpcio                             1.64.0
2024-05-23T06:00:54: gunicorn                           22.0.0
2024-05-23T06:00:54: h5py                               3.11.0
2024-05-23T06:00:54: humanfriendly                      10.0
2024-05-23T06:00:54: idna                               3.7
2024-05-23T06:00:54: importlib-metadata                 7.0.0
2024-05-23T06:00:54: importlib_resources                6.4.0
2024-05-23T06:00:54: inference-schema                   1.7.2
2024-05-23T06:00:54: ipykernel                          6.29.4
2024-05-23T06:00:54: psutil                             5.8.0
2024-05-23T06:00:54: ptyprocess                         0.7.0
2024-05-23T06:00:54: pure-eval                          0.2.2
2024-05-23T06:00:54: py-cpuinfo                         5.0.0
2024-05-23T06:00:54: py-spy                             0.3.12
2024-05-23T06:00:54: pyarrow                            16.1.0
2024-05-23T06:00:54: pyasn1                             0.6.0
2024-05-23T06:00:54: pyasn1_modules                     0.4.0
2024-05-23T06:00:54: pycparser                          2.21
2024-05-23T06:00:54: pydantic                           2.7.1
2024-05-23T06:00:54: pydantic_core                      2.18.2
2024-05-23T06:00:54: pydantic-settings                  2.2.1
2024-05-23T06:00:54: Pygments                           2.18.0
2024-05-23T06:00:54: PyJWT                              2.8.0
2024-05-23T06:00:54: PyNaCl                             1.5.0
2024-05-23T06:00:54: pyOpenSSL                          24.1.0
2024-05-23T06:00:54: pyparsing                          3.1.2
2024-05-23T06:00:54: PySocks                            1.7.1
2024-05-23T06:00:54: python-dateutil                    2.8.2
2024-05-23T06:00:54: python-dotenv                      1.0.1
2024-05-23T06:00:54: pytz                               2023.3.post1
2024-05-23T06:00:54: PyYAML                             6.0.1
2024-05-23T06:00:54: pyzmq                              26.0.3
2024-05-23T06:00:54: referencing                        0.35.1
2024-05-23T06:00:54: requests                           2.32.2
2024-05-23T06:00:54: requests-oauthlib                  2.0.0
2024-05-23T06:00:54: rpds-py                            0.18.1
2024-05-23T06:00:54: rsa                                4.9
2024-05-23T06:00:54: scikit-learn                       1.3.2
2024-05-23T06:00:54: scikit-learn-intelex               2024.3.0
2024-05-23T06:00:54: scipy                              1.10.1
2024-05-23T06:00:54: seaborn                            0.13.2
2024-05-23T06:00:54: SecretStorage                      3.3.3
2024-05-23T06:00:54: setuptools                         68.0.0
2024-05-23T06:00:54: six                                1.16.0
2024-05-23T06:00:54: smmap                              5.0.1
2024-05-23T06:00:54: sqlparse                           0.5.0
2024-05-23T06:00:54: stack-data                         0.6.3
2024-05-23T06:00:54: tabulate                           0.9.0
2024-05-23T06:00:54: tbb                                2021.12.0
2024-05-23T06:00:54: tensorboard                        2.12.3
2024-05-23T06:00:54: tensorboard-data-server            0.7.2
2024-05-23T06:00:54: tensorflow                         2.12.0
2024-05-23T06:00:54: tensorflow-estimator               2.12.0
2024-05-23T06:00:54: tensorflow-io-gcs-filesystem       0.34.0
2024-05-23T06:00:54: termcolor                          2.4.0
2024-05-23T06:00:54: threadpoolctl                      3.5.0
2024-05-23T06:00:54: torch-tb-profiler                  0.4.3
2024-05-23T06:00:54: tornado                            6.4
2024-05-23T06:00:54: tqdm                               4.62.3
2024-05-23T06:00:54: traitlets                          5.14.3
2024-05-23T06:00:54: typing_extensions                  4.11.0
2024-05-23T06:00:54: tzdata                             2024.1
2024-05-23T06:00:54: urllib3                            1.26.18
2024-05-23T06:00:54: wcwidth                            0.2.13
2024-05-23T06:00:54: Werkzeug                           3.0.3
2024-05-23T06:00:54: wheel                              0.38.4
2024-05-23T06:00:54: wrapt                              1.14.1
2024-05-23T06:00:54: zipp                               3.18.2
